# %%
import requests
from bs4 import BeautifulSoup
import csv
import time
import pandas as pd

# %%
listing_base_url = 'https://ozflatmates.com/{}'

# Open the CSV file in write mode
with open('room_listings.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    
    # Write the header row, including Publish Date and Listing ID
    writer.writerow(['Listing ID', 'Room Description', 'Suburb', 'Price', 'Publish Date'])

    # Base URL for room listings pages
    base_url = 'https://ozflatmates.com/rooms-for-rent/sydney/page-{}'

    # Loop through each page
    for page_num in range(1, 7):  # Loop through pages 1 to 6
        # Format the URL for the current page
        url = base_url.format(page_num)
        print(f"Scraping page {page_num}: {url}")

        # Fetch the webpage
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')

        # Find all room listings on the current page
        room_listings = soup.find_all('div', class_='room__wide listing-container')

        # Loop through each listing and extract information
        for room in room_listings:
            # Extract room suburb
            room_suburb = room.find('h3', class_='room-sublocation mobile-room-sublocation')
            suburb_text = room_suburb.text.strip().split('-')[-1].strip() if room_suburb else "N/A"

            # Extract room price
            room_price = room.find('div', class_='room-price')
            price_text = room_price.text.strip().replace('$', '') if room_price else "N/A"

            # Extract room name
            room_description = room.find('h4', class_='room-name')
            name_text = room_description.text.strip() if room_description else "N/A"

            # Extract listing URL and extract ID 
            listing_link = room.find('a', href=True)
            listing_url = listing_link['href'] if listing_link else None
            listing_id = listing_url.split('/')[-1] if listing_url else "N/A"

            # Construct the individual listing URL using the Listing ID
            if listing_id != "N/A":
                listing_page_url = listing_base_url.format(listing_id)
                print(f"Fetching listing page: {listing_page_url}")

                # Fetch the individual listing page to get the publish date
                listing_response = requests.get(listing_page_url)
                listing_soup = BeautifulSoup(listing_response.content, 'html.parser')

                # Extract publish date 
                publish_date_element = listing_soup.find(text=lambda x: x and "Published on" in x)
                publish_date = publish_date_element.split("Published on")[1].strip() if publish_date_element else "N/A"
            else:
                publish_date = "N/A"

            # Write the room details to the CSV file
            writer.writerow([listing_id, name_text, suburb_text, price_text, publish_date])

            # Print the details
            print(f"Listing ID: {listing_id}")
            print(f"Room Name: {name_text}")
            print(f"Suburb: {suburb_text}")
            print(f"Price: {price_text}")
            print(f"Publish Date: {publish_date}")
            print("-" * 40)

        # Add a delay between requests to avoid overwhelming the server
        time.sleep(2)  # Sleep for 2 seconds between page requests
# Out:
# Scraping page 1: https://ozflatmates.com/rooms-for-rent/sydney/page-1
# Fetching listing page: https://ozflatmates.com/ID32860
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_23924\2528342436.py:55: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   publish_date_element = listing_soup.find(text=lambda x: x and "Published on" in x)
# Listing ID: ID32860
# Room Name: Sydney CBD Room
# Suburb: Sydney
# Price: 450
# Publish Date: 15.10.2024
# ----------------------------------------
# Fetching listing page: https://ozflatmates.com/ID
07.2024
# ----------------------------------------
# Fetching listing page: https://ozflatmates.com/ID32433
# Listing ID: ID32433
# Room Name: Room for Rent - Tallawong/Schofields
# Suburb: Schofields
# Price: 260
# Publish Date: 25.07.2024
# ----------------------------------------
# Scraping page 5: https://ozflatmates.com/rooms-for-rent/sydney/page-5
# Fetching listing page: https://ozflatmates.com/ID32434
# Listing ID: ID32434
# Room Name: Queen Room with Balcony for Rent - Tallawong/Sc...
# Suburb: Schofields
# Price: 260
# Publish Date: 25.07.2024
# ----------------------------------------
# Fetching listing page: https://ozflatmates.com/ID32431
# Listing ID: ID32431
# Room Name: Room for Rent,
# Suburb: Cabramatta
# Price: 220
# Publish Date: 25.07.2024
# ----------------------------------------
# Fetching listing page: https://ozflatmates.com/ID32405
# Listing ID: ID32405
# Room Name: Parramatta, Furnished private room, private bat...
# Suburb: Parramatta
# Price: 250
# Publish Date: 22.07.2024
# ----------------------------------------
# Fetching listing page: https://ozflatmates.com/ID32400
# Listing ID: ID32400
# Room Name: Stunning flat 1 month rental
# Suburb: Queenscliff
# Price: 550
# Publish Date: 22.07.2024
# ----------------------------------------
# Fetching listing page: https://ozflatmates.com/ID32390
# Listing ID: ID32390
# Room Name: (BOY) 123 Abercrombie, Chippendale, Room availa...
# Suburb: Chippendale
# Price: 310
# Publish Date: 18.07.2024
# ----------------------------------------
# Fetching listing page: https://ozflatmates.com/ID32373
# Listing ID: ID32373
# Room Name: 315 including bills - 1 bedroom available in sh...
# Suburb: Rydalmere
# Price: 315
# Publish Date: 17.07.2024
# ----------------------------------------
# Fetching listing page: https://ozflatmates.com/ID32374
# Listing ID: ID32374
# Room Name: Comfy room
# Suburb: Gordon
# Price: 315
# Publish Date: 17.07.2024
# ----------------------------------------
# Fetching listing page: https://ozflatmates.com/ID32367
# Listing ID: ID32367
# Room Name: Huge Ensuite Room With Balcony
# Suburb: Mortlake
# Price: 410
# Publish Date: 14.07.2024
# ----------------------------------------
# Fetching listing page: https://ozflatmates.com/ID32361
# Listing ID: ID32361
# Room Name: Room for rent
# Suburb: Bankstown
# Price: 260
# Publish Date: 11.07.2024
# ----------------------------------------
# Fetching listing page: https://ozflatmates.com/ID32586
# Listing ID: ID32586
# Room Name: Private Room in Rozelle
# Suburb: Rozelle
# Price: 260
# Publish Date: 01.10.2024
# ----------------------------------------
# Scraping page 6: https://ozflatmates.com/rooms-for-rent/sydney/page-6
# Fetching listing page: https://ozflatmates.com/ID32761
# Listing ID: ID32761
# Room Name: $365 per week room in Alexandria
# Suburb: Alexandria
# Price: 360
# Publish Date: 25.09.2024
# ----------------------------------------
# Fetching listing page: https://ozflatmates.com/ID32646
# Listing ID: ID32646
# Room Name: Ensuite room
# Suburb: Pyrmont
# Price: 500
# Publish Date: 03.09.2024
# ----------------------------------------
# Fetching listing page: https://ozflatmates.com/ID32420
# Listing ID: ID32420
# Room Name: Available immediately
# Suburb: Saint Marys
# Price: 270
# Publish Date: 27.08.2024
# ----------------------------------------
# Fetching listing page: https://ozflatmates.com/ID32532
# Listing ID: ID32532
# Room Name: Ground floor Unit for one Month stay.
# Suburb: West Ryde
# Price: 499
# Publish Date: 10.08.2024
# ----------------------------------------
# Fetching listing page: https://ozflatmates.com/ID32497
# Listing ID: ID32497
# Room Name: Private room for rent in Cobbitty
# Suburb: Oran Park
# Price: 300
# Publish Date: 04.08.2024
# ----------------------------------------
# Fetching listing page: https://ozflatmates.com/ID32445
# Listing ID: ID32445
# Room Name: excellent room in prime building in pyrmont
# Suburb: Pyrmont
# Price: 500
# Publish Date: 28.07.2024
# ----------------------------------------

# %%
df = pd.read_csv('room_listings.csv')

# %%
df.head()
# Out:
#   Listing ID                                   Room Description  \
# 0    ID32860                                    Sydney CBD Room
# 1    ID32846       Parramatta, quiet modern single room, female
# 2    ID32838  Active Christian Guys house, ideal for Medic o...
# 3    ID32835           Homey Room in 2 Bedroom 2 Bathroom Flat!
# 4    ID32844                    Beautiful North Bondi apartment
#
#            Suburb  Price Publish Date
# 0          Sydney    450   15.10.2024
# 1       Granville    300   15.10.2024
# 2  Wentworthville    390   13.10.2024
# 3       Rydalmere    340   13.10.2024
# 4     North Bondi    600   13.10.2024

# %%
print(df.shape)
print(df.isna().sum())
print(df.dtypes)
# Out:
# (56, 5)
# Listing ID          0
# Room Description    0
# Suburb              0
# Price               0
# Publish Date        0
# dtype: int64
# Listing ID          object
# Room Description    object
# Suburb              object
# Price                int64
# Publish Date        object
# dtype: object

# %%
df['Publish Date'] = pd.to_datetime(df['Publish Date'], format='%d.%m.%Y')
df.head()
# Out:
#   Listing ID                                   Room Description  \
# 0    ID32860                                    Sydney CBD Room
# 1    ID32846       Parramatta, quiet modern single room, female
# 2    ID32838  Active Christian Guys house, ideal for Medic o...
# 3    ID32835           Homey Room in 2 Bedroom 2 Bathroom Flat!
# 4    ID32844                    Beautiful North Bondi apartment
#
#            Suburb  Price Publish Date
# 0          Sydney    450   2024-10-15
# 1       Granville    300   2024-10-15
# 2  Wentworthville    390   2024-10-13
# 3       Rydalmere    340   2024-10-13
# 4     North Bondi    600   2024-10-13

# %%
price_by_suburb = df.groupby('Suburb').agg(Min_Price = ('Price', 'min'), Max_Price = ('Price', 'max'), Average_Price=('Price', 'mean')).astype(int).sort_values(by='Average_Price')
print(price_by_suburb)
# Out:
#                    Min_Price  Max_Price  Average_Price
# Suburb
# Carlingford              200        200            200
# North Strathfield        200        200            200
# Merrylands West          230        230            230
# Cambridge Park           230        230            230
# Cabramatta               220        300            240
# Cherrybrook              240        240            240
# Cranebrook               250        250            250
# Maroubra                 250        250            250
# Hurstville               250        250            250
# Bankstown                250        260            255
# Rozelle                  260        260            260
# Schofields               260        260            260
# Saint Marys              270        270            270
# Penrith                  250        300            275
# Penshurst                295        295            295
# Bardia                   295        295            295
# Parramatta               250        360            299
# Oran Park                300        300            300
# Kogarah                  300        300            300
# Homebush West            300        300            300
# Granville                300        300            300
# Erskineville             300        300            300
# West Hoxton              300        300            300
# Chippendale              310        310            310
# Gordon                   315        315            315
# Double Bay               325        325            325
# Rydalmere                315        340            327
# Rooty Hill               330        330            330
# Dee Why                  340        340            340
# Saint Ives               350        350            350
# West Ryde                295        499            363
# Ryde                     375        375            375
# Wentworthville           390        390            390
# Mortlake                 410        410            410
# Sydney                   400        450            425
# Alexandria               360        600            480
# Pyrmont                  500        500            500
# North Sydney             530        530            530
# Queenscliff              550        550            550
# North Bondi              600        600            600

# %% [markdown]
# -->
# Sydney's room rents vary widely based on proximity to the CBD, demand for beachside locations, infrastructure, and lifestyle factors, with inner-city and coastal areas having the highest prices. Meanwhile, suburbs like Carlingford, North Strathfield, and Cabramatta have lower rents because they're further from the CBD, and have more affordable housing, appealing to budget-conscious renters.
